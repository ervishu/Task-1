# %% [markdown]
# ###Problem Statement : Predict the percentage of an student based on the no. of study hours.

# %%
#Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ####Lode Dataset

# %%
# Reading data from remote link
url_path = "http://bit.ly/w-data"
data = pd.read_csv(url_path)
print("Data Load Successfully")
# Out:
# Data Load Successfully

# %%
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# ###This is a simple linear  regression task as it involves just 2 variables. Hours and scores

# %% [markdown]
# Regression analysis is a subfield of supervised machine learning. It aims to model the relationship between a certain number of features and a continuous target variable.

# %%
data.plot(x="Hours",y="Scores",style='o')
plt.title("Hours VS Percentage")
plt.xlabel("Hours")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# A linear relationship (or linear association) is a statistical term used to describe a straight-line relationship between two variables. Linear relationships can be expressed either in a graphical format or as a mathematical equation of the form y = mx + b

# %% [markdown]
# ###Preparing dataset

# %% [markdown]
# The Dataset is Divided into x(input) and y(output) variable

# %%
x = data.iloc[:,0].values
y = data.iloc[:,1].values
x=x.reshape(-1,1)
y=y.reshape(-1,1)

# %%
x
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
y
# Out:
# array([[21],
#        [47],
#        [27],
#        [75],
#        [30],
#        [20],
#        [88],
#        [60],
#        [81],
#        [25],
#        [85],
#        [62],
#        [41],
#        [42],
#        [17],
#        [95],
#        [30],
#        [24],
#        [67],
#        [69],
#        [30],
#        [54],
#        [35],
#        [76],
#        [86]])

# %% [markdown]
# ####Dataset split for training and testing

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(x, y, 
                            test_size=0.2, random_state=0)

# %%
print(X_train.shape)

print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (20, 1)
# (5, 1)
# (20, 1)
# (5, 1)

# %% [markdown]
# Here the target varibale(Scores) is dependent on independent varibale(Hours)
# Hence we have use linear regression for this dataset.
#
#  Regression is a method of modelling a target value based on independent predictors. It is a statistical tool which is used to find out the relationship between the outcome variable also known as the dependent variable, and one or more variable often called as independent variables.  This method is mostly used for forecasting and finding out cause and effect relationship between variables. Regression techniques mostly differ based on the number of independent variables and the type of relationship between the independent and dependent variables.

# %%
#import library
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
print("Training successfuly Done!!!!!!")
print("Training Score:",LR.score(X_train,y_train))
# Out:
# Training successfuly Done!!!!!!
# Training Score: 0.9515510725211553

# %%
y_pred = LR.predict(X_test)

# %%
y_pred
# Out:
# array([[16.88414476],
#        [33.73226078],
#        [75.357018  ],
#        [26.79480124],
#        [60.49103328]])

# %%
from sklearn.metrics import r2_score
print("Test Score:",r2_score(y_test, y_pred))
# Out:
# Test Score: 0.9454906892105354

# %%
print("What will be predicted score if a student studies for 9.25 hrs/ day? ")
output = LR.predict([[9.25]])
print("if a student studies for 9.25 hrs/ day?:",output)
# Out:
# What will be predicted score if a student studies for 9.25 hrs/ day?
# if a student studies for 9.25 hrs/ day?: [[93.69173249]]

# %%
#Visualizing the Training set results 
plt.scatter(X_train,y_train, color='red')
plt.plot(X_train,LR.predict(X_train), color='blue')
plt.title('Study Hours VS Score (Training set)')
plt.xlabel('Study Hours')
plt.ylabel('Score')
plt.show()

# %%
#Visualizing the Training set results 
plt.scatter(X_test,y_test, color='red')
plt.plot(X_test,LR.predict(X_test), color='blue')
plt.title('Study Hours VS Score (Testing set)')
plt.xlabel('Study Hours')
plt.ylabel('Score')
plt.show()
